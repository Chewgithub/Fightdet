# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/ysin/code/Chewgithub/Fightdet/notebooks'

# %%
from IPython.display import HTML
from Fightdet.video_to_numpy import video_to_numpy
from Fightdet.ysget_optical_flow import get_optical_flow as gof

# %%
url = '../raw_data/SNGRni0hBUM_0.avi'
url2 = '../raw_data/Suv_mMs8J9g_0.avi'

# %%
cap = cv2.VideoCapture(url)

# %%
testing1 = video_to_numpy(url)
testing1.shape
# Out:
# (150, 224, 224, 3)

# %%
testing2 = gof(testing1)
testing2.shape
# Out:
# (150, 224, 224, 2)

# %%
# testing3 = np.concatenate((testing1,testing2),axis=-1)
# testing3.shape

# %%
plt.imshow(testing1[143])

# %%
testing2
# Out:
# array([[[[ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          ...,
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ]],
#
#         [[ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          ...,
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ]],
#
#         [[ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          ...,
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ]],
#
#         ...,
#
#         [[ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          ...,
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ],
#          [ 80.29038 , 108.07664 ]],
#
# ...

# %%
np.unique(testing2).shape
# Out:
# (7159996,)
